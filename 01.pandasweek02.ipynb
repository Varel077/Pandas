# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.4.1

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  3  3  1  7
# 1  8  1  9  5  9
# 2  7  2  3  1  2
# 3  1  6  2  5  5
# 4  9  9  9  9  2

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  7  1  3  3  6
# 1  9  5  9  1  8
# 2  2  1  3  2  7
# 3  5  5  2  6  1
# 4  2  9  9  9  9

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  9  9  9  9  2
# 3  1  6  2  5  5
# 2  7  2  3  1  2
# 1  8  1  9  5  9
# 0  6  3  3  1  7

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  9  9  9  9  2
# 1  1  6  2  5  5
# 2  7  2  3  1  2
# 3  8  1  9  5  9
# 4  6  3  3  1  7

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.4.1

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  5  3  8  8  1
# 1  7  4  8  7  2
# 2  2  9  3  5  1
# 3  4  7  8  9  4
# 4  4  1  1  2  9

# %%
df.rename(columns={'C':'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  5  3     8  8  1
# 1  7  4     8  7  2
# 2  2  9     3  5  1
# 3  4  7     8  9  4
# 4  4  1     1  2  9

# %%
df.rename(columns={'A':'Nama', 'B':'Alamat', 'D':'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     5       3  8     8  1
# 1     7       4  8     7  2
# 2     2       9  3     5  1
# 3     4       7  8     9  4
# 4     4       1  1     2  9

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
#    index         A         B         C         D
# 0      0  0.463197 -0.014126 -1.253583 -0.625694
# 1      1 -1.064294 -1.312001       NaN       NaN
# 2      2  0.755962  0.638435  0.091473  1.373740
# 3      3  0.412721 -0.288418  0.840935  1.244033
# 4      4       NaN  0.200468 -2.255023       NaN

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0  0.463197 -0.014126 -1.253583 -0.625694
# 1  1 -1.064294 -1.312001       NaN       NaN
# 2  2  0.755962  0.638435  0.091473  1.373740
# 3  3  0.412721 -0.288418  0.840935  1.244033
# 4  4       NaN  0.200468 -2.255023       NaN

# %%
df_backup = df.copy(deep=True)

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#    Z         A         B         C         D
# 0  0  0.463197 -0.014126 -1.253583 -0.625694
# 2  2  0.755962  0.638435  0.091473  1.373740
# 3  3  0.412721 -0.288418  0.840935  1.244033
# 5  5  0.909498 -0.056087 -0.384254 -0.457146
# 6  6 -1.357455 -0.464572 -0.939150  0.853504

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.166667
# B    0.333333
# C    0.233333
# D    0.233333
# dtype: float64

# %%
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.4.1

# %%
data = {'A':[15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np.nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['A'] == df['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df['A'].equals(df['B'])
# Out:
# True

# %%
df1 = df.copy(deep=True)

df.equals(df1)
# Out:
# True

# %%
df == df1
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
