# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.4.1

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  3  6  6  2  7
# 1  4  7  8  8  8
# 2  3  4  6  9  3
# 3  4  5  1  2  7
# 4  1  1  8  9  9

# %%
tuple('ABCDE')
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
df.add_prefix('kolom_')
# Out:
#    kolom_A  kolom_B  kolom_C  kolom_D  kolom_E
# 0        3        6        6        2        7
# 1        4        7        8        8        8
# 2        3        4        6        9        3
# 3        4        5        1        2        7
# 4        1        1        8        9        9

# %%
df.add_suffix('_field')
# Out:
#    A_field  B_field  C_field  D_field  E_field
# 0        3        6        6        2        7
# 1        4        7        8        8        8
# 2        3        4        6        9        3
# 3        4        5        1        2        7
# 4        1        1        8        9        9

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.4.1

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 5, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  1  1  3  1  1
# 1  4  1  2  2  3
# 2  1  2  1  2  4
# 3  4  4  2  3  4
# 4  1  4  2  1  2
# 5  3  1  3  1  2
# 6  1  2  3  4  1
# 7  1  4  4  3  4
# 8  2  2  1  3  3
# 9  2  2  3  3  1

# %%
df[(df['A'] == 1) | (df['A'] == 3)]
# Out:
#    A  B  C  D  E
# 0  1  1  3  1  1
# 2  1  2  1  2  4
# 4  1  4  2  1  2
# 5  3  1  3  1  2
# 6  1  2  3  4  1
# 7  1  4  4  3  4

# %%
df[df['A'].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 0  1  1  3  1  1
# 2  1  2  1  2  4
# 4  1  4  2  1  2
# 5  3  1  3  1  2
# 6  1  2  3  4  1
# 7  1  4  4  3  4

# %%
df[~df['A'].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 1  4  1  2  2  3
# 3  4  4  2  3  4
# 8  2  2  1  3  3
# 9  2  2  3  3  1

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
data = {'col1':['1', '2', '3', 'teks'], 
        'col2':['1', '2', '3', '4']}

df = pd.DataFrame(data)
df
# Out:
#    col1 col2
# 0     1    1
# 1     2    2
# 2     3    3
# 3  teks    4

# %%
df.dtypes
# Out:
# col1    object
# col2    object
# dtype: object

# %%
df_x = df.astype({'col2':'int'})
df_x
# Out:
#    col1  col2
# 0     1     1
# 1     2     2
# 2     3     3
# 3  teks     4

# %%
df_x.dtypes
# Out:
# col1    object
# col2     int64
# dtype: object

# %%
df.apply(pd.to_numeric, errors='coerce')
# Out:
#    col1  col2
# 0   1.0     1
# 1   2.0     2
# 2   3.0     3
# 3   NaN     4

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.4.1

# %%
n_rows = 5
n_cols = 2
cols = ['bil_pecahan', 'bil_bulat']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)

df['bil_pecahan'] = df['bil_pecahan'].astype('float')

df.index = pd.date_range(start='2024-10-01', periods=n_rows, freq='h')

df = df.reset_index()
df['teks'] = list('ABCDE')

df
# Out:
#                 index  bil_pecahan  bil_bulat teks
# 0 2024-10-01 00:00:00          6.0         14    A
# 1 2024-10-01 01:00:00         12.0         13    B
# 2 2024-10-01 02:00:00          6.0         14    C
# 3 2024-10-01 03:00:00          7.0          7    D
# 4 2024-10-01 04:00:00          2.0          3    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil_pecahan           float64
# bil_bulat               int32
# teks                   object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#    bil_pecahan  bil_bulat
# 0          6.0         14
# 1         12.0         13
# 2          6.0         14
# 3          7.0          7
# 4          2.0          3

# %%
df.select_dtypes(include='float')
# Out:
#    bil_pecahan
# 0          6.0
# 1         12.0
# 2          6.0
# 3          7.0
# 4          2.0

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0         14
# 1         13
# 2         14
# 3          7
# 4          3

# %%
df.select_dtypes(include='object')
# Out:
#   teks
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2024-10-01 00:00:00
# 1 2024-10-01 01:00:00
# 2 2024-10-01 02:00:00
# 3 2024-10-01 03:00:00
# 4 2024-10-01 04:00:00

# %%
df.select_dtypes(include=['number', 'object'])
# Out:
#    bil_pecahan  bil_bulat teks
# 0          6.0         14    A
# 1         12.0         13    B
# 2          6.0         14    C
# 3          7.0          7    D
# 4          2.0          3    E
