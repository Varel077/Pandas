# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
from sklearn.datasets import load_iris

# %%
df.groupby('Species')['PetalLengthCm'].count().to_frame()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.groupby('Species')['PetalLengthCm'].count().to_frame()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
df.groupby('Species')['PetalLengthCm'].mean().to_frame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.groupby('Species')['PetalLengthCm'].mean().to_frame()
#
# NameError: name 'df' is not defined

# %%
from dataclasses import _DataclassFactory


_DataclassFactory.groupby('Species')['PetalLengthCm'].median().to_frame()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from dataclasses import _DataclassFactory
#       4 _DataclassFactory.groupby('Species')['PetalLengthCm'].median().to_frame()
#
# ImportError: cannot import name '_DataclassFactory' from 'dataclasses' (c:\Program Files\Python314\Lib\dataclasses.py)

# %%
df.groupby('Species')['PetalLengthCm'].agg(['count', 'mean', 'median'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.groupby('Species')['PetalLengthCm'].agg(['count', 'mean', 'median'])
#
# NameError: name 'df' is not defined

# %%
df.groupby('Species')['PetalLengthCm'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.groupby('Species')['PetalLengthCm'].describe()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
df_titanic = pd.read_csv('./data/titanicfull.csv')
df_titanic.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_titanic = pd.read_csv('./data/titanicfull.csv')
#       2 df_titanic.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_iris = pd.read_csv('./data/Iris.csv')
df_iris.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_iris = pd.read_csv('./data/Iris.csv')
#       2 df_iris.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_titanic.info(memory_usage='deep')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_titanic.info(memory_usage='deep')
#
# NameError: name 'df_titanic' is not defined

# %%
df_iris.info(memory_usage='deep')

df_titanic.memory_usage(deep=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_iris.info(memory_usage='deep')
#       3 df_titanic.memory_usage(deep=True)
#
# NameError: name 'df_iris' is not defined

# %%
df_iris.memory_usage(deep=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_iris.memory_usage(deep=True)
#
# NameError: name 'df_iris' is not defined

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
d = {'kolom_satu':[1, 2, 3, 4, 5], 
     'kolom dua':[10, 20, 30, 40, 50]}
df = pd.DataFrame(d)
df
# Out:
#    kolom_satu  kolom dua
# 0           1         10
# 1           2         20
# 2           3         30
# 3           4         40
# 4           5         50

# %%
df.query('kolom_satu > 2')
# Out:
#    kolom_satu  kolom dua
# 2           3         30
# 3           4         40
# 4           5         50

# %%
df.query('`kolom dua` > 30')
# Out:
#    kolom_satu  kolom dua
# 3           4         40
# 4           5         50

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
s = pd.Series(range(1591683521, 1592201921, 3600))
s = pd.to_datetime(s, unit='s')
s.head()
# Out:
# 0   2020-06-09 06:18:41
# 1   2020-06-09 07:18:41
# 2   2020-06-09 08:18:41
# 3   2020-06-09 09:18:41
# 4   2020-06-09 10:18:41
# dtype: datetime64[ns]

# %%
s = s.dt.tz_localize('UTC')
s.head()
# Out:
# 0   2020-06-09 06:18:41+00:00
# 1   2020-06-09 07:18:41+00:00
# 2   2020-06-09 08:18:41+00:00
# 3   2020-06-09 09:18:41+00:00
# 4   2020-06-09 10:18:41+00:00
# dtype: datetime64[ns, UTC]

# %%
s = s.dt.tz_convert('Asia/Jakarta')
s.head()
# Out:
# 0   2020-06-09 13:18:41+07:00
# 1   2020-06-09 14:18:41+07:00
# 2   2020-06-09 15:18:41+07:00
# 3   2020-06-09 16:18:41+07:00
# 4   2020-06-09 17:18:41+07:00
# dtype: datetime64[ns, Asia/Jakarta]

# %%
s = s.dt.tz_convert('Australia/Hobart')
s.head()
# Out:
# 0   2020-06-09 16:18:41+10:00
# 1   2020-06-09 17:18:41+10:00
# 2   2020-06-09 18:18:41+10:00
# 3   2020-06-09 19:18:41+10:00
# 4   2020-06-09 20:18:41+10:00
# dtype: datetime64[ns, Australia/Hobart]
